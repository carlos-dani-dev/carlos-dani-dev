# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-dani-dev/carlos-dani-dev/blob/main/notebooks/Operacao_9_Word_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Monte o Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Download do dataset
# !gdown --id 1_Elg5O_H0fJ1mIWEKkb6q4ul9x7SIhnk -O /content/drive/MyDrive/pln_data/
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1_Elg5O_H0fJ1mIWEKkb6q4ul9x7SIhnk
# To: /content/drive/MyDrive/pln_data/b2w_reviews_samsung_cleaned.csv
# 100% 801k/801k [00:00<00:00, 77.7MB/s]

# %%
# !pip install gensim
# Executar no início dos notebooks
# !pip install gensim sentence-transformers
# !pip install wordcloud plotly

# Para downloads do dataset
# !pip install gdown
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 54.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 15.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# Bibliotecas principais
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Pré-processamento
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
# Verificar uso de RAM
# !cat /proc/meminfo | head -n 3

# Verificar GPU disponível
# !nvidia-smi
# Out:
# MemTotal:       13289416 kB
# MemFree:         5571456 kB
# MemAvailable:   11124576 kB
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# TensorFlow/Keras
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization

# Word Embeddings
import gensim
from gensim.models import Word2Vec, Doc2Vec
from sentence_transformers import SentenceTransformer

# NLTK
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
reviews = pd.read_csv('/content/drive/MyDrive/PLN_B2W_Reviews/data/processed/b2w_reviews_samsung_modified.csv')
reviews
# Out:
#                                             review_text  overall_rating  \
# 0     Uma tela impecável. Se sua prioridade é tela e...               4
# 1     Melhor custo benefício. Exatamente  como anunc...               5
# 2     Muito útil, para pesquisas e baixar publicaçõe...               5
# 3     A entrega sempre no prazo e muitas vezes até a...               4
# 4     Recomendo tanto o produto quanto a loja, produ...               4
# ...                                                 ...             ...
# 5748  O produto é muito bom. O designer é perfeito. ...               5
# 5749  Excelente produto. Acima do esperado, Recomend...               5
# 5750  Amei o produto muito bom ,chegou bem antes do ...               5
# 5751  Qualidade de imagem e som são excelentes, além...               5
# 5752  Continuo acreditando nas lojas americanas.Tenh...               4
#
#       recommend_to_a_friend
# 0                         1
# 1                         1
# ...

# %%
# Carregar Word2Vec CBOW pré-treinado (dimensão 100)
w2v_cbow = gensim.models.KeyedVectors.load_word2vec_format(
    "cbow_s100.txt", binary=False
)

# Carregar Word2Vec Skip-gram pré-treinado
w2v_sg = gensim.models.KeyedVectors.load_word2vec_format(
    "skip_s100.txt", binary=False
)

# Carregar GloVe (convertido para word2vec format)
glove = gensim.models.KeyedVectors.load_word2vec_format(
    "glove_s100.txt", binary=False
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2214337491.py in <cell line: 0>()
#       1 # Carregar Word2Vec CBOW pré-treinado (dimensão 100)
# ----> 2 w2v_cbow = gensim.models.KeyedVectors.load_word2vec_format(
#       3     "cbow_s100.txt", binary=False
#       4 )
#       5
#
# /usr/local/lib/python3.12/dist-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1717
#    1718         """
# -> 1719         return _load_word2vec_format(
#    1720             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721             limit=limit, datatype=datatype, no_header=no_header,
#
# ...
